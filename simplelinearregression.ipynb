# %%
#Simple linear regression
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing dataset
dataset = pd.read_csv('50_Startups.csv')
df = dataset.replace(to_replace = ['New York','California','Florida'],value = ['-1','0','1'])
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
#Splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Training the simple linear regression model on the training set
#from sklearn.linear_model import LinearRegression
#import statsmodels
#import statsmodels
#regressor = LinearRegression()
#model=regressor.fit(X_train, y_train)
#model.summary()

# %%
#from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
#regressor = LinearRegression()
#model=regressor.fit(X_train, y_train)
X_train_sm = sm.add_constant(X_train)
model=sm.OLS(y_train,X_train_sm).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     154.7
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           1.17e-18
# Time:                        15:55:23   Log-Likelihood:                -347.37
# No. Observations:                  33   AIC:                             704.7
# Df Residuals:                      28   BIC:                             712.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.082e+05   1704.855     63.447      0.000    1.05e+05    1.12e+05
# x1          3.986e+04   2910.047     13.697      0.000    3.39e+04    4.58e+04
# x2          1386.1156   1857.756      0.746      0.462   -2419.325    5191.556
# x3          3319.6060   2689.341      1.234      0.227   -2189.259    8828.471
# x4          1678.0844   1852.077      0.906      0.373   -2115.722    5471.891
# ==============================================================================
# Omnibus:                       14.710   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.900
# Skew:                          -1.010   Prob(JB):                     1.07e-05
# Kurtosis:                       6.546   Cond. No.                         3.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.preprocessing import OneHotEncoder

#creating instance of one-hot-encoder
encoder = OneHotEncoder(handle_unknown='ignore')

#perform one-hot encoding on 'team' column 
encoder_df = pd.DataFrame(encoder.fit_transform(dataset[['State']]).toarray())

#merge one-hot encoded columns back with original DataFrame
final_df = dataset.join(encoder_df)
final_df.drop('State', axis=1, inplace=True)
final_df = final_df.iloc[:, [0,1,2,4,5,6,3]]
#final_df['column1'] = df['column1'].shift(-1)
#view final df
print(final_df)
# Out:
#     R&D Spend  Administration  Marketing Spend    0    1    2     Profit
# 0   165349.20       136897.80        471784.10  0.0  0.0  1.0  192261.83
# 1   162597.70       151377.59        443898.53  1.0  0.0  0.0  191792.06
# 2   153441.51       101145.55        407934.54  0.0  1.0  0.0  191050.39
# 3   144372.41       118671.85        383199.62  0.0  0.0  1.0  182901.99
# 4   142107.34        91391.77        366168.42  0.0  1.0  0.0  166187.94
# 5   131876.90        99814.71        362861.36  0.0  0.0  1.0  156991.12
# 6   134615.46       147198.87        127716.82  1.0  0.0  0.0  156122.51
# 7   130298.13       145530.06        323876.68  0.0  1.0  0.0  155752.60
# 8   120542.52       148718.95        311613.29  0.0  0.0  1.0  152211.77
# 9   123334.88       108679.17        304981.62  1.0  0.0  0.0  149759.96
# 10  101913.08       110594.11        229160.95  0.0  1.0  0.0  146121.95
# 11  100671.96        91790.61        249744.55  1.0  0.0  0.0  144259.40
# 12   93863.75       127320.38        249839.44  0.0  1.0  0.0  141585.52
# 13   91992.39       135495.07        252664.93  1.0  0.0  0.0  134307.35
# 14  119943.24       156547.42        256512.92  0.0  1.0  0.0  132602.65
# 15  114523.61       122616.84        261776.23  0.0  0.0  1.0  129917.04
# 16   78013.11       121597.55        264346.06  1.0  0.0  0.0  126992.93
# 17   94657.16       145077.58        282574.31  0.0  0.0  1.0  125370.37
# 18   91749.16       114175.79        294919.57  0.0  1.0  0.0  124266.90
# 19   86419.70       153514.11             0.00  0.0  0.0  1.0  122776.86
# 20   76253.86       113867.30        298664.47  1.0  0.0  0.0  118474.03
# 21   78389.47       153773.43        299737.29  0.0  0.0  1.0  111313.02
# 22   73994.56       122782.75        303319.26  0.0  1.0  0.0  110352.25
# 23   67532.53       105751.03        304768.73  0.0  1.0  0.0  108733.99
# 24   77044.01        99281.34        140574.81  0.0  0.0  1.0  108552.04
# 25   64664.71       139553.16        137962.62  1.0  0.0  0.0  107404.34
# 26   75328.87       144135.98        134050.07  0.0  1.0  0.0  105733.54
# 27   72107.60       127864.55        353183.81  0.0  0.0  1.0  105008.31
# 28   66051.52       182645.56        118148.20  0.0  1.0  0.0  103282.38
# 29   65605.48       153032.06        107138.38  0.0  0.0  1.0  101004.64
# 30   61994.48       115641.28         91131.24  0.0  1.0  0.0   99937.59
# 31   61136.38       152701.92         88218.23  0.0  0.0  1.0   97483.56
# 32   63408.86       129219.61         46085.25  1.0  0.0  0.0   97427.84
# 33   55493.95       103057.49        214634.81  0.0  1.0  0.0   96778.92
# 34   46426.07       157693.92        210797.67  1.0  0.0  0.0   96712.80
# 35   46014.02        85047.44        205517.64  0.0  0.0  1.0   96479.51
# 36   28663.76       127056.21        201126.82  0.0  1.0  0.0   90708.19
# 37   44069.95        51283.14        197029.42  1.0  0.0  0.0   89949.14
# 38   20229.59        65947.93        185265.10  0.0  0.0  1.0   81229.06
# 39   38558.51        82982.09        174999.30  1.0  0.0  0.0   81005.76
# 40   28754.33       118546.05        172795.67  1.0  0.0  0.0   78239.91
# 41   27892.92        84710.77        164470.71  0.0  1.0  0.0   77798.83
# 42   23640.93        96189.63        148001.11  1.0  0.0  0.0   71498.49
# 43   15505.73       127382.30         35534.17  0.0  0.0  1.0   69758.98
# 44   22177.74       154806.14         28334.72  1.0  0.0  0.0   65200.33
# 45    1000.23       124153.04          1903.93  0.0  0.0  1.0   64926.08
# 46    1315.46       115816.21        297114.46  0.0  1.0  0.0   49490.75
# 47       0.00       135426.92             0.00  1.0  0.0  0.0   42559.73
# 48     542.05        51743.15             0.00  0.0  0.0  1.0   35673.41
# 49       0.00       116983.80         45173.06  1.0  0.0  0.0   14681.40

# %%
X = final_df.iloc[:, :-1].values
y = final_df.iloc[:, -1].values

# %%
#Splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
#from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
#regressor = LinearRegression()
#model=regressor.fit(X_train, y_train)
X_train_sm = sm.add_constant(X_train)
model=sm.OLS(y_train,X_train_sm).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     122.0
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           1.18e-17
# Time:                        16:08:01   Log-Likelihood:                -347.02
# No. Observations:                  33   AIC:                             706.0
# Df Residuals:                      27   BIC:                             715.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.076e+04   6815.093      4.513      0.000    1.68e+04    4.47e+04
# x1             0.8284      0.061     13.580      0.000       0.703       0.954
# x2             0.0504      0.073      0.687      0.498      -0.100       0.201
# x3             0.0222      0.021      1.063      0.297      -0.021       0.065
# x4          8390.0715   3063.044      2.739      0.011    2105.225    1.47e+04
# x5          1.432e+04   4442.781      3.222      0.003    5200.872    2.34e+04
# x6          8051.8402   3420.475      2.354      0.026    1033.604    1.51e+04
# ==============================================================================
# Omnibus:                       13.089   Durbin-Watson:                   2.107
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.973
# Skew:                          -0.992   Prob(JB):                     0.000206
# Kurtosis:                       5.899   Cond. No.                     1.47e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.11e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
#regressor = LinearRegression()
#model=regressor.fit(X_train, y_train)
X_train_sm = sm.add_constant(X_train)
model=sm.OLS(y_train,X_train_sm).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     122.0
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           1.18e-17
# Time:                        16:10:22   Log-Likelihood:                -347.02
# No. Observations:                  33   AIC:                             706.0
# Df Residuals:                      27   BIC:                             715.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.082e+05   1718.155     62.956      0.000    1.05e+05    1.12e+05
# x1          4.014e+04   2955.706     13.580      0.000    3.41e+04    4.62e+04
# x2          1288.9766   1876.679      0.687      0.498   -2561.651    5139.604
# x3          2933.4228   2758.319      1.063      0.297   -2726.181    8593.026
# x4          -551.2813   1043.594     -0.528      0.602   -2692.559    1589.996
# x5          1728.0283   1472.893      1.173      0.251   -1294.098    4750.155
# x6          -706.2432   1126.672     -0.627      0.536   -3017.984    1605.497
# ==============================================================================
# Omnibus:                       13.089   Durbin-Watson:                   2.107
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.973
# Skew:                          -0.992   Prob(JB):                     0.000206
# Kurtosis:                       5.899   Cond. No.                     7.78e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.14e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#importing dataset
dataset = pd.read_csv('50_Startups.csv')
df = dataset.replace(to_replace = ['New York','California','Florida'],value = ['120000','130000','14'])
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
#Splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
#regressor = LinearRegression()
#model=regressor.fit(X_train, y_train)
X_train_sm = sm.add_constant(X_train)
model=sm.OLS(y_train,X_train_sm).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     157.8
# Date:                Thu, 25 Aug 2022   Prob (F-statistic):           8.94e-19
# Time:                        16:17:24   Log-Likelihood:                -347.05
# No. Observations:                  33   AIC:                             704.1
# Df Residuals:                      28   BIC:                             711.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.082e+05   1688.604     64.057      0.000    1.05e+05    1.12e+05
# x1          4.001e+04   2841.256     14.081      0.000    3.42e+04    4.58e+04
# x2          1284.9707   1844.308      0.697      0.492   -2492.923    5062.864
# x3          2999.0930   2693.793      1.113      0.275   -2518.891    8517.077
# x4         -2127.3504   1812.004     -1.174      0.250   -5839.073    1584.372
# ==============================================================================
# Omnibus:                       12.745   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.630
# Skew:                          -1.002   Prob(JB):                     0.000404
# Kurtosis:                       5.711   Cond. No.                         3.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
